# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                         "Current Description":description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ghanzi
# Processing Record 2 of Set 1 | deer lake
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | tuatapere
# Processing Record 5 of Set 1 | richards bay
# Processing Record 6 of Set 1 | yulara
# Processing Record 7 of Set 1 | cape town
# Processing Record 8 of Set 1 | santa cruz
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | bonavista
# Processing Record 11 of Set 1 | galesong
# Processing Record 12 of Set 1 | torbay
# Processing Record 13 of Set 1 | butaritari
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | tonj
# Processing Record 16 of Set 1 | puerto ayora
# Processing Record 17 of Set 1 | saint-philippe
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | fortuna
# Processing Record 20 of Set 1 | kuala krai
# City not found. Skipping...
# Processing Record 21 of Set 1 | altay
# Processing Record 22 of Set 1 | qaanaaq
# Processing Record 23 of Set 1 | carnarvon
# Processing Record 24 of Set 1 | flinders
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 1 | guerrero negro
# Processing Record 28 of Set 1 | gargzdai
# Processing Record 29 of Set 1 | tasiilaq
# Processing Record 30 of Set 1 | buala
# Processing Record 31 of Set 1 | hohhot
# Processing Record 32 of Set 1 | sioux lookout
# Processing Record 33 of Set 1 | barrow
# Processing Record 34 of Set 1 | souillac
# Processing Record 35 of Set 1 | nikolskoye
# Processing Record 36 of Set 1 | san isidro
# Processing Record 37 of Set 1 | mahebourg
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | nemuro
# Processing Record 40 of Set 1 | mehamn
# Processing Record 41 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 42 of Set 1 | rikitea
# Processing Record 43 of Set 1 | labuhan
# Processing Record 44 of Set 1 | hovd
# Processing Record 45 of Set 1 | eureka
# Processing Record 46 of Set 1 | hithadhoo
# Processing Record 47 of Set 1 | bluff
# Processing Record 48 of Set 1 | dingle
# Processing Record 49 of Set 1 | rocha
# Processing Record 50 of Set 1 | lar
# Processing Record 1 of Set 2 | vaini
# Processing Record 2 of Set 2 | port alfred
# Processing Record 3 of Set 2 | broome
# Processing Record 4 of Set 2 | iquique
# Processing Record 5 of Set 2 | new norfolk
# Processing Record 6 of Set 2 | hilo
# Processing Record 7 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 2 | bengkulu
# Processing Record 9 of Set 2 | tiarei
# Processing Record 10 of Set 2 | grindavik
# Processing Record 11 of Set 2 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 12 of Set 2 | hobart
# Processing Record 13 of Set 2 | cabo san lucas
# Processing Record 14 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 2 | jacutinga
# Processing Record 16 of Set 2 | platanos
# Processing Record 17 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 2 | chapais
# Processing Record 19 of Set 2 | manono
# Processing Record 20 of Set 2 | mount gambier
# Processing Record 21 of Set 2 | bardiyah
# Processing Record 22 of Set 2 | ponta do sol
# Processing Record 23 of Set 2 | guasdualito
# Processing Record 24 of Set 2 | castro
# Processing Record 25 of Set 2 | basco
# Processing Record 26 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 2 | bowen
# Processing Record 28 of Set 2 | kurud
# Processing Record 29 of Set 2 | springbok
# Processing Record 30 of Set 2 | milos
# Processing Record 31 of Set 2 | chuy
# Processing Record 32 of Set 2 | geraldton
# Processing Record 33 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 2 | jatai
# Processing Record 36 of Set 2 | berdigestyakh
# Processing Record 37 of Set 2 | port augusta
# Processing Record 38 of Set 2 | arraial do cabo
# Processing Record 39 of Set 2 | lusambo
# Processing Record 40 of Set 2 | borkenes
# Processing Record 41 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 2 | mar del plata
# Processing Record 43 of Set 2 | muros
# Processing Record 44 of Set 2 | goderich
# Processing Record 45 of Set 2 | muzhi
# Processing Record 46 of Set 2 | kitimat
# Processing Record 47 of Set 2 | yellowknife
# Processing Record 48 of Set 2 | hualmay
# Processing Record 49 of Set 2 | bukachacha
# Processing Record 50 of Set 2 | sur
# Processing Record 1 of Set 3 | sao francisco do sul
# Processing Record 2 of Set 3 | khatanga
# Processing Record 3 of Set 3 | kapaa
# Processing Record 4 of Set 3 | pervomayskoye
# Processing Record 5 of Set 3 | provideniya
# Processing Record 6 of Set 3 | hermanus
# Processing Record 7 of Set 3 | ahipara
# Processing Record 8 of Set 3 | praya
# Processing Record 9 of Set 3 | gigmoto
# Processing Record 10 of Set 3 | bubaque
# Processing Record 11 of Set 3 | xinzhou
# Processing Record 12 of Set 3 | matara
# Processing Record 13 of Set 3 | longyearbyen
# Processing Record 14 of Set 3 | jamestown
# Processing Record 15 of Set 3 | tautira
# Processing Record 16 of Set 3 | saldanha
# Processing Record 17 of Set 3 | chaiya
# Processing Record 18 of Set 3 | lagoa
# Processing Record 19 of Set 3 | padang
# Processing Record 20 of Set 3 | mana
# Processing Record 21 of Set 3 | mirabad
# Processing Record 22 of Set 3 | rorvik
# Processing Record 23 of Set 3 | leh
# Processing Record 24 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 3 | mikumi
# Processing Record 26 of Set 3 | yar-sale
# Processing Record 27 of Set 3 | waipawa
# Processing Record 28 of Set 3 | aksu
# Processing Record 29 of Set 3 | santa marta
# Processing Record 30 of Set 3 | waidhofen
# Processing Record 31 of Set 3 | kavaratti
# Processing Record 32 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 3 | sao filipe
# Processing Record 34 of Set 3 | kruisfontein
# Processing Record 35 of Set 3 | sitka
# Processing Record 36 of Set 3 | port elizabeth
# Processing Record 37 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 3 | utiroa
# City not found. Skipping...
# Processing Record 39 of Set 3 | bethel
# Processing Record 40 of Set 3 | lavrentiya
# Processing Record 41 of Set 3 | muisne
# Processing Record 42 of Set 3 | broken hill
# Processing Record 43 of Set 3 | norman wells
# Processing Record 44 of Set 3 | tuktoyaktuk
# Processing Record 45 of Set 3 | margate
# Processing Record 46 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 3 | hobyo
# Processing Record 48 of Set 3 | anloga
# Processing Record 49 of Set 3 | riyadh
# Processing Record 50 of Set 3 | mayo
# Processing Record 1 of Set 4 | grafton
# Processing Record 2 of Set 4 | saint-paul
# Processing Record 3 of Set 4 | avarua
# Processing Record 4 of Set 4 | bambous virieux
# Processing Record 5 of Set 4 | puerto baquerizo moreno
# Processing Record 6 of Set 4 | upernavik
# Processing Record 7 of Set 4 | faanui
# Processing Record 8 of Set 4 | uddevalla
# Processing Record 9 of Set 4 | kungsbacka
# Processing Record 10 of Set 4 | chokurdakh
# Processing Record 11 of Set 4 | launceston
# Processing Record 12 of Set 4 | cayenne
# Processing Record 13 of Set 4 | uniao da victoria
# City not found. Skipping...
# Processing Record 14 of Set 4 | port hedland
# Processing Record 15 of Set 4 | airai
# Processing Record 16 of Set 4 | cidreira
# Processing Record 17 of Set 4 | port macquarie
# Processing Record 18 of Set 4 | sakit
# Processing Record 19 of Set 4 | port-gentil
# Processing Record 20 of Set 4 | the pas
# Processing Record 21 of Set 4 | los llanos de aridane
# Processing Record 22 of Set 4 | lebu
# Processing Record 23 of Set 4 | yola
# Processing Record 24 of Set 4 | aktash
# Processing Record 25 of Set 4 | isangel
# Processing Record 26 of Set 4 | bichura
# Processing Record 27 of Set 4 | miri
# Processing Record 28 of Set 4 | clyde river
# Processing Record 29 of Set 4 | thompson
# Processing Record 30 of Set 4 | kichmengskiy gorodok
# Processing Record 31 of Set 4 | sibu
# Processing Record 32 of Set 4 | coquimbo
# Processing Record 33 of Set 4 | sao raimundo nonato
# Processing Record 34 of Set 4 | ryotsu
# Processing Record 35 of Set 4 | nanortalik
# Processing Record 36 of Set 4 | petauke
# Processing Record 37 of Set 4 | nome
# Processing Record 38 of Set 4 | lolodorf
# Processing Record 39 of Set 4 | port hardy
# Processing Record 40 of Set 4 | mercedes
# Processing Record 41 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 4 | sao jose da coroa grande
# Processing Record 43 of Set 4 | te anau
# Processing Record 44 of Set 4 | mogadishu
# Processing Record 45 of Set 4 | shingu
# Processing Record 46 of Set 4 | hamilton
# Processing Record 47 of Set 4 | pavlohrad
# Processing Record 48 of Set 4 | georgetown
# Processing Record 49 of Set 4 | saint george
# Processing Record 50 of Set 4 | marawi
# Processing Record 1 of Set 5 | pevek
# Processing Record 2 of Set 5 | panama city
# Processing Record 3 of Set 5 | victoria
# Processing Record 4 of Set 5 | tuy hoa
# Processing Record 5 of Set 5 | nueve de julio
# Processing Record 6 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 7 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 5 | phetchaburi
# Processing Record 9 of Set 5 | narasannapeta
# Processing Record 10 of Set 5 | dzerzhinskoye
# Processing Record 11 of Set 5 | haines junction
# Processing Record 12 of Set 5 | karratha
# Processing Record 13 of Set 5 | bilma
# Processing Record 14 of Set 5 | ilulissat
# Processing Record 15 of Set 5 | egvekinot
# Processing Record 16 of Set 5 | narsingi
# Processing Record 17 of Set 5 | tigre
# Processing Record 18 of Set 5 | hami
# Processing Record 19 of Set 5 | kandrian
# Processing Record 20 of Set 5 | kaitangata
# Processing Record 21 of Set 5 | saint-denis
# Processing Record 22 of Set 5 | colares
# Processing Record 23 of Set 5 | araouane
# Processing Record 24 of Set 5 | chipinge
# Processing Record 25 of Set 5 | iberia
# Processing Record 26 of Set 5 | beihai
# Processing Record 27 of Set 5 | ballina
# Processing Record 28 of Set 5 | pyshma
# Processing Record 29 of Set 5 | east london
# Processing Record 30 of Set 5 | bergen
# Processing Record 31 of Set 5 | loei
# Processing Record 32 of Set 5 | male
# Processing Record 33 of Set 5 | tarko-sale
# Processing Record 34 of Set 5 | kotaparh
# Processing Record 35 of Set 5 | ancud
# Processing Record 36 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 37 of Set 5 | betioky
# Processing Record 38 of Set 5 | joshimath
# Processing Record 39 of Set 5 | novoagansk
# Processing Record 40 of Set 5 | linhares
# Processing Record 41 of Set 5 | atuona
# Processing Record 42 of Set 5 | kegayli
# City not found. Skipping...
# Processing Record 43 of Set 5 | kawana waters
# City not found. Skipping...
# Processing Record 44 of Set 5 | shaunavon
# Processing Record 45 of Set 5 | luderitz
# Processing Record 46 of Set 5 | paita
# Processing Record 47 of Set 5 | camana
# Processing Record 48 of Set 5 | laredo
# Processing Record 49 of Set 5 | linxia
# Processing Record 50 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 1 of Set 6 | vardo
# Processing Record 2 of Set 6 | kidal
# Processing Record 3 of Set 6 | tiznit
# Processing Record 4 of Set 6 | tarata
# Processing Record 5 of Set 6 | mbandaka
# Processing Record 6 of Set 6 | varhaug
# Processing Record 7 of Set 6 | huarmey
# Processing Record 8 of Set 6 | taoudenni
# Processing Record 9 of Set 6 | lasem
# Processing Record 10 of Set 6 | paamiut
# Processing Record 11 of Set 6 | uglovskoye
# Processing Record 12 of Set 6 | bilibino
# Processing Record 13 of Set 6 | bay saint louis
# Processing Record 14 of Set 6 | dikson
# Processing Record 15 of Set 6 | maniitsoq
# Processing Record 16 of Set 6 | tabou
# Processing Record 17 of Set 6 | rosarito
# Processing Record 18 of Set 6 | hailar
# Processing Record 19 of Set 6 | lasa
# Processing Record 20 of Set 6 | grand baie
# Processing Record 21 of Set 6 | salalah
# Processing Record 22 of Set 6 | letlhakane
# Processing Record 23 of Set 6 | labuan
# Processing Record 24 of Set 6 | saskylakh
# Processing Record 25 of Set 6 | chabahar
# Processing Record 26 of Set 6 | christchurch
# Processing Record 27 of Set 6 | kandi
# Processing Record 28 of Set 6 | westport
# Processing Record 29 of Set 6 | charagua
# Processing Record 30 of Set 6 | hanyang
# Processing Record 31 of Set 6 | felidhoo
# City not found. Skipping...
# Processing Record 32 of Set 6 | katsuura
# Processing Record 33 of Set 6 | narsaq
# Processing Record 34 of Set 6 | kodiak
# Processing Record 35 of Set 6 | oranjemund
# Processing Record 36 of Set 6 | ribeira grande
# Processing Record 37 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 38 of Set 6 | xuddur
# Processing Record 39 of Set 6 | yaring
# Processing Record 40 of Set 6 | meulaboh
# Processing Record 41 of Set 6 | pangnirtung
# Processing Record 42 of Set 6 | kyren
# Processing Record 43 of Set 6 | buraydah
# Processing Record 44 of Set 6 | kinablangan
# Processing Record 45 of Set 6 | kahului
# Processing Record 46 of Set 6 | yangambi
# Processing Record 47 of Set 6 | tucupita
# Processing Record 48 of Set 6 | korla
# Processing Record 49 of Set 6 | honiara
# Processing Record 50 of Set 6 | kem
# Processing Record 1 of Set 7 | vestnes
# Processing Record 2 of Set 7 | severo-kurilsk
# Processing Record 3 of Set 7 | calatayud
# Processing Record 4 of Set 7 | bethanien
# Processing Record 5 of Set 7 | mackay
# Processing Record 6 of Set 7 | hofn
# Processing Record 7 of Set 7 | olafsvik
# Processing Record 8 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 9 of Set 7 | korop
# Processing Record 10 of Set 7 | kununurra
# Processing Record 11 of Set 7 | manicore
# Processing Record 12 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 13 of Set 7 | itarema
# Processing Record 14 of Set 7 | sterling
# Processing Record 15 of Set 7 | krasnoselkup
# Processing Record 16 of Set 7 | goundi
# Processing Record 17 of Set 7 | teya
# Processing Record 18 of Set 7 | fairbanks
# Processing Record 19 of Set 7 | ambulu
# Processing Record 20 of Set 7 | posevnaya
# Processing Record 21 of Set 7 | la ronge
# Processing Record 22 of Set 7 | moanda
# Processing Record 23 of Set 7 | candawaga
# City not found. Skipping...
# Processing Record 24 of Set 7 | maneadero
# Processing Record 25 of Set 7 | gornopravdinsk
# Processing Record 26 of Set 7 | pyapon
# Processing Record 27 of Set 7 | tiksi
# Processing Record 28 of Set 7 | moundou
# Processing Record 29 of Set 7 | mozarlandia
# Processing Record 30 of Set 7 | rio gallegos
# Processing Record 31 of Set 7 | hasaki
# Processing Record 32 of Set 7 | bousso
# Processing Record 33 of Set 7 | rockland
# Processing Record 34 of Set 7 | ca mau
# Processing Record 35 of Set 7 | babu
# Processing Record 36 of Set 7 | moctezuma
# Processing Record 37 of Set 7 | cherskiy
# Processing Record 38 of Set 7 | divnogorsk
# Processing Record 39 of Set 7 | puranpur
# Processing Record 40 of Set 7 | tocopilla
# Processing Record 41 of Set 7 | caninde de sao francisco
# Processing Record 42 of Set 7 | nampula
# Processing Record 43 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 44 of Set 7 | tsienyane
# City not found. Skipping...
# Processing Record 45 of Set 7 | bandarbeyla
# Processing Record 46 of Set 7 | port shepstone
# Processing Record 47 of Set 7 | turayf
# Processing Record 48 of Set 7 | kucove
# Processing Record 49 of Set 7 | comodoro rivadavia
# Processing Record 50 of Set 7 | gravelbourg
# Processing Record 1 of Set 8 | we
# City not found. Skipping...
# Processing Record 2 of Set 8 | cleethorpes
# Processing Record 3 of Set 8 | beaverlodge
# Processing Record 4 of Set 8 | trinidad
# Processing Record 5 of Set 8 | pisco
# Processing Record 6 of Set 8 | carupano
# Processing Record 7 of Set 8 | priiskovyy
# Processing Record 8 of Set 8 | vostok
# Processing Record 9 of Set 8 | mosquera
# Processing Record 10 of Set 8 | bathsheba
# Processing Record 11 of Set 8 | west wendover
# Processing Record 12 of Set 8 | aguilas
# Processing Record 13 of Set 8 | les cayes
# Processing Record 14 of Set 8 | abu kamal
# Processing Record 15 of Set 8 | atyashevo
# Processing Record 16 of Set 8 | masuda
# Processing Record 17 of Set 8 | mongoumba
# Processing Record 18 of Set 8 | road town
# Processing Record 19 of Set 8 | along
# Processing Record 20 of Set 8 | roma
# Processing Record 21 of Set 8 | ayan
# Processing Record 22 of Set 8 | kavieng
# Processing Record 23 of Set 8 | palmas bellas
# Processing Record 24 of Set 8 | upata
# Processing Record 25 of Set 8 | kenora
# Processing Record 26 of Set 8 | sambava
# Processing Record 27 of Set 8 | penzance
# Processing Record 28 of Set 8 | luau
# Processing Record 29 of Set 8 | kibakwe
# Processing Record 30 of Set 8 | maldonado
# Processing Record 31 of Set 8 | one hundred mile house
# City not found. Skipping...
# Processing Record 32 of Set 8 | kananga
# Processing Record 33 of Set 8 | jardim
# Processing Record 34 of Set 8 | adrar
# Processing Record 35 of Set 8 | makasar
# Processing Record 36 of Set 8 | karwar
# Processing Record 37 of Set 8 | hudiksvall
# Processing Record 38 of Set 8 | cascas
# Processing Record 39 of Set 8 | gararu
# Processing Record 40 of Set 8 | cumaribo
# City not found. Skipping...
# Processing Record 41 of Set 8 | lexington
# Processing Record 42 of Set 8 | corinto
# Processing Record 43 of Set 8 | ulladulla
# Processing Record 44 of Set 8 | lata
# Processing Record 45 of Set 8 | port blair
# Processing Record 46 of Set 8 | vieques
# Processing Record 47 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 8 | havelock
# Processing Record 49 of Set 8 | clinton
# Processing Record 50 of Set 8 | saint-louis
# Processing Record 1 of Set 9 | buchanan
# Processing Record 2 of Set 9 | ilek
# Processing Record 3 of Set 9 | oksfjord
# Processing Record 4 of Set 9 | dukat
# Processing Record 5 of Set 9 | greenville
# Processing Record 6 of Set 9 | lethem
# Processing Record 7 of Set 9 | sistranda
# Processing Record 8 of Set 9 | chicama
# Processing Record 9 of Set 9 | beloha
# Processing Record 10 of Set 9 | xunchang
# Processing Record 11 of Set 9 | lompoc
# Processing Record 12 of Set 9 | verkhnevilyuysk
# Processing Record 13 of Set 9 | olinda
# Processing Record 14 of Set 9 | cocobeach
# Processing Record 15 of Set 9 | ivanovka
# Processing Record 16 of Set 9 | taltal
# Processing Record 17 of Set 9 | cedar city
# Processing Record 18 of Set 9 | sinnamary
# Processing Record 19 of Set 9 | tshikapa
# Processing Record 20 of Set 9 | matamoros
# Processing Record 21 of Set 9 | ust-kuyga
# Processing Record 22 of Set 9 | tezu
# Processing Record 23 of Set 9 | komsomolskiy
# Processing Record 24 of Set 9 | rio de janeiro
# Processing Record 25 of Set 9 | champerico
# Processing Record 26 of Set 9 | chas
# Processing Record 27 of Set 9 | kampot
# Processing Record 28 of Set 9 | evensk
# Processing Record 29 of Set 9 | ostersund
# Processing Record 30 of Set 9 | diapaga
# Processing Record 31 of Set 9 | saurimo
# Processing Record 32 of Set 9 | henties bay
# Processing Record 33 of Set 9 | bayevo
# Processing Record 34 of Set 9 | mount isa
# Processing Record 35 of Set 9 | trincomalee
# Processing Record 36 of Set 9 | camocim
# Processing Record 37 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 38 of Set 9 | san patricio
# Processing Record 39 of Set 9 | fort nelson
# Processing Record 40 of Set 9 | berlevag
# Processing Record 41 of Set 9 | posse
# Processing Record 42 of Set 9 | zhezkazgan
# Processing Record 43 of Set 9 | vestmannaeyjar
# Processing Record 44 of Set 9 | axim
# Processing Record 45 of Set 9 | moldovita
# Processing Record 46 of Set 9 | iqaluit
# Processing Record 47 of Set 9 | el faiyum
# City not found. Skipping...
# Processing Record 48 of Set 9 | redding
# Processing Record 49 of Set 9 | churapcha
# Processing Record 50 of Set 9 | burkhala
# City not found. Skipping...
# Processing Record 1 of Set 10 | zhashkiv
# Processing Record 2 of Set 10 | kolchugino
# Processing Record 3 of Set 10 | pacific grove
# Processing Record 4 of Set 10 | longyan
# Processing Record 5 of Set 10 | manta
# Processing Record 6 of Set 10 | constitucion
# Processing Record 7 of Set 10 | faya
# Processing Record 8 of Set 10 | namibe
# Processing Record 9 of Set 10 | walvis bay
# Processing Record 10 of Set 10 | port lincoln
# Processing Record 11 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 10 | iguape
# Processing Record 13 of Set 10 | samarai
# Processing Record 14 of Set 10 | miramar
# Processing Record 15 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 16 of Set 10 | ribas do rio pardo
# Processing Record 17 of Set 10 | manavalakurichi
# Processing Record 18 of Set 10 | jalu
# Processing Record 19 of Set 10 | manado
# Processing Record 20 of Set 10 | rehoboth
# Processing Record 21 of Set 10 | san policarpo
# Processing Record 22 of Set 10 | hibbing
# Processing Record 23 of Set 10 | alofi
# Processing Record 24 of Set 10 | flateby
# Processing Record 25 of Set 10 | pasighat
# Processing Record 26 of Set 10 | saint-tite
# Processing Record 27 of Set 10 | ita
# Processing Record 28 of Set 10 | belyy yar
# Processing Record 29 of Set 10 | inhambane
# Processing Record 30 of Set 10 | encruzilhada
# Processing Record 31 of Set 10 | umm lajj
# Processing Record 32 of Set 10 | petatlan
# Processing Record 33 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 34 of Set 10 | porto velho
# Processing Record 35 of Set 10 | vung tau
# Processing Record 36 of Set 10 | ciudad guayana
# Processing Record 37 of Set 10 | soroti
# Processing Record 38 of Set 10 | mokobeng
# Processing Record 39 of Set 10 | rio grande
# Processing Record 40 of Set 10 | martapura
# Processing Record 41 of Set 10 | dovolnoye
# Processing Record 42 of Set 10 | carutapera
# Processing Record 43 of Set 10 | itaituba
# Processing Record 44 of Set 10 | yatou
# Processing Record 45 of Set 10 | najran
# Processing Record 46 of Set 10 | la tuque
# Processing Record 47 of Set 10 | qandala
# Processing Record 48 of Set 10 | almaznyy
# Processing Record 49 of Set 10 | boulder city
# Processing Record 50 of Set 10 | pumiao
# Processing Record 1 of Set 11 | zletovo
# Processing Record 2 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 3 of Set 11 | monatele
# City not found. Skipping...
# Processing Record 4 of Set 11 | dzaoudzi
# Processing Record 5 of Set 11 | kargil
# Processing Record 6 of Set 11 | yuzhno-kurilsk
# Processing Record 7 of Set 11 | roshchino
# Processing Record 8 of Set 11 | laguna de perlas
# Processing Record 9 of Set 11 | trairi
# Processing Record 10 of Set 11 | ramasukha
# City not found. Skipping...
# Processing Record 11 of Set 11 | ngama
# Processing Record 12 of Set 11 | aklavik
# Processing Record 13 of Set 11 | necochea
# Processing Record 14 of Set 11 | manokwari
# Processing Record 15 of Set 11 | esperance
# Processing Record 16 of Set 11 | dalvik
# Processing Record 17 of Set 11 | tecoanapa
# Processing Record 18 of Set 11 | hutchinson
# Processing Record 19 of Set 11 | amlame
# Processing Record 20 of Set 11 | santa lucia
# Processing Record 21 of Set 11 | hambantota
# Processing Record 22 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 11 | mangrol
# Processing Record 24 of Set 11 | akyab
# Processing Record 25 of Set 11 | romny
# Processing Record 26 of Set 11 | bhadrachalam
# Processing Record 27 of Set 11 | salinopolis
# Processing Record 28 of Set 11 | talnakh
# Processing Record 29 of Set 11 | morwell
# Processing Record 30 of Set 11 | saint anthony
# Processing Record 31 of Set 11 | vila franca do campo
# Processing Record 32 of Set 11 | itoman
# Processing Record 33 of Set 11 | siyabuswa
# Processing Record 34 of Set 11 | north bend
# Processing Record 35 of Set 11 | senneterre
# Processing Record 36 of Set 11 | bangkalan
# Processing Record 37 of Set 11 | puri
# Processing Record 38 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 39 of Set 11 | ongandjera
# Processing Record 40 of Set 11 | tucuman
# Processing Record 41 of Set 11 | half moon bay
# Processing Record 42 of Set 11 | kalmunai
# Processing Record 43 of Set 11 | manamadurai
# Processing Record 44 of Set 11 | nouakchott
# Processing Record 45 of Set 11 | kadiri
# Processing Record 46 of Set 11 | krasnovishersk
# Processing Record 47 of Set 11 | rongcheng
# Processing Record 48 of Set 11 | makakilo city
# Processing Record 49 of Set 11 | bodden town
# Processing Record 50 of Set 11 | portland
# Processing Record 1 of Set 12 | teluk nibung
# Processing Record 2 of Set 12 | liwale
# Processing Record 3 of Set 12 | baie-comeau
# Processing Record 4 of Set 12 | jacareacanga
# Processing Record 5 of Set 12 | abaza
# Processing Record 6 of Set 12 | karpogory
# Processing Record 7 of Set 12 | kensington
# Processing Record 8 of Set 12 | mwanza
# Processing Record 9 of Set 12 | san cristobal
# Processing Record 10 of Set 12 | deputatskiy
# Processing Record 11 of Set 12 | alice springs
# Processing Record 12 of Set 12 | safakulevo
# Processing Record 13 of Set 12 | narayanganj
# Processing Record 14 of Set 12 | nancha
# Processing Record 15 of Set 12 | yamada
# Processing Record 16 of Set 12 | igarka
# Processing Record 17 of Set 12 | saint-pierre
# Processing Record 18 of Set 12 | caravelas
# Processing Record 19 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 20 of Set 12 | blagoyevo
# Processing Record 21 of Set 12 | sao joao da barra
# Processing Record 22 of Set 12 | gamba
# Processing Record 23 of Set 12 | arkhangelsk
# Processing Record 24 of Set 12 | andenes
# Processing Record 25 of Set 12 | bay roberts
# Processing Record 26 of Set 12 | xining
# Processing Record 27 of Set 12 | mabaruma
# Processing Record 28 of Set 12 | becerril
# Processing Record 29 of Set 12 | sompeta
# Processing Record 30 of Set 12 | altamont
# Processing Record 31 of Set 12 | kalabo
# Processing Record 32 of Set 12 | mangan
# Processing Record 33 of Set 12 | do gonbadan
# Processing Record 34 of Set 12 | la rochelle
# Processing Record 35 of Set 12 | perieni
# Processing Record 36 of Set 12 | sadovoye
# Processing Record 37 of Set 12 | shalinskoye
# Processing Record 38 of Set 12 | grand-santi
# Processing Record 39 of Set 12 | skibotn
# Processing Record 40 of Set 12 | puerto escondido
# Processing Record 41 of Set 12 | bogorodskoye
# Processing Record 42 of Set 12 | lanciano
# Processing Record 43 of Set 12 | itabera
# Processing Record 44 of Set 12 | salcia tudor
# Processing Record 45 of Set 12 | zarubino
# Processing Record 46 of Set 12 | wana
# Processing Record 47 of Set 12 | beringovskiy
# Processing Record 48 of Set 12 | touros
# Processing Record 49 of Set 12 | nisia floresta
# Processing Record 50 of Set 12 | mpanda
# Processing Record 1 of Set 13 | juneau
# Processing Record 2 of Set 13 | naze
# Processing Record 3 of Set 13 | sibolga
# Processing Record 4 of Set 13 | borshchiv
# Processing Record 5 of Set 13 | marsabit
# Processing Record 6 of Set 13 | high level
# Processing Record 7 of Set 13 | ladario
# Processing Record 8 of Set 13 | fort-shevchenko
# Processing Record 9 of Set 13 | talakan
# Processing Record 10 of Set 13 | marabba
# Processing Record 11 of Set 13 | umm kaddadah
# Processing Record 12 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 13 of Set 13 | kaeo
# Processing Record 14 of Set 13 | loreto
# Processing Record 15 of Set 13 | ugoofaaru
# Processing Record 16 of Set 13 | guarapari
# Processing Record 17 of Set 13 | fleury-les-aubrais
# Processing Record 18 of Set 13 | villa maria
# Processing Record 19 of Set 13 | camacupa
# Processing Record 20 of Set 13 | nevelsk
# Processing Record 21 of Set 13 | nevsehir
# Processing Record 22 of Set 13 | valley
# Processing Record 23 of Set 13 | idenao
# Processing Record 24 of Set 13 | podeni
# Processing Record 25 of Set 13 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 26 of Set 13 | alekseyevka
# Processing Record 27 of Set 13 | zhigansk
# Processing Record 28 of Set 13 | kirakira
# Processing Record 29 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 30 of Set 13 | biograd na moru
# Processing Record 31 of Set 13 | verkhoyansk
# Processing Record 32 of Set 13 | poum
# Processing Record 33 of Set 13 | kathu
# Processing Record 34 of Set 13 | tazovskiy
# Processing Record 35 of Set 13 | rathdrum
# Processing Record 36 of Set 13 | guiglo
# Processing Record 37 of Set 13 | atar
# Processing Record 38 of Set 13 | boende
# Processing Record 39 of Set 13 | batsfjord
# Processing Record 40 of Set 13 | baculin
# Processing Record 41 of Set 13 | nauta
# Processing Record 42 of Set 13 | pimentel
# Processing Record 43 of Set 13 | ust-tsilma
# Processing Record 44 of Set 13 | kailua
# Processing Record 45 of Set 13 | monterey
# Processing Record 46 of Set 13 | ferkessedougou
# Processing Record 47 of Set 13 | doha
# Processing Record 48 of Set 13 | balkhash
# Processing Record 49 of Set 13 | ban nahin
# Processing Record 50 of Set 13 | porto novo
# Processing Record 1 of Set 14 | banjar
# Processing Record 2 of Set 14 | northam
# Processing Record 3 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 4 of Set 14 | urucara
# Processing Record 5 of Set 14 | tuma
# Processing Record 6 of Set 14 | brigantine
# Processing Record 7 of Set 14 | merritt island
# Processing Record 8 of Set 14 | vancouver
# Processing Record 9 of Set 14 | diego de almagro
# Processing Record 10 of Set 14 | coihaique
# Processing Record 11 of Set 14 | zhuanghe
# Processing Record 12 of Set 14 | reo
# Processing Record 13 of Set 14 | buon me thuot
# City not found. Skipping...
# Processing Record 14 of Set 14 | kongsberg
# Processing Record 15 of Set 14 | dolores
# Processing Record 16 of Set 14 | oriximina
# Processing Record 17 of Set 14 | zolotinka
# City not found. Skipping...
# Processing Record 18 of Set 14 | leningradskiy
# Processing Record 19 of Set 14 | lagdo
# Processing Record 20 of Set 14 | asau
# Processing Record 21 of Set 14 | ajaccio
# Processing Record 22 of Set 14 | ohara
# Processing Record 23 of Set 14 | adre
# Processing Record 24 of Set 14 | san andres
# Processing Record 25 of Set 14 | dwarka
# Processing Record 26 of Set 14 | lincoln
# Processing Record 27 of Set 14 | vapnyarka
# Processing Record 28 of Set 14 | usinsk
# Processing Record 29 of Set 14 | ketchikan
# Processing Record 30 of Set 14 | santo tomas
# Processing Record 31 of Set 14 | novopokrovka
# Processing Record 32 of Set 14 | rawson
# Processing Record 33 of Set 14 | movila
# Processing Record 34 of Set 14 | sisimiut
# Processing Record 35 of Set 14 | warmbad
# Processing Record 36 of Set 14 | suluq
# Processing Record 37 of Set 14 | vadgaon
# Processing Record 38 of Set 14 | san quintin
# Processing Record 39 of Set 14 | tucuma
# Processing Record 40 of Set 14 | bentong
# Processing Record 41 of Set 14 | bereda
# Processing Record 42 of Set 14 | laguna
# Processing Record 43 of Set 14 | vila velha
# Processing Record 44 of Set 14 | la sarre
# Processing Record 45 of Set 14 | la grande
# Processing Record 46 of Set 14 | lahat
# Processing Record 47 of Set 14 | mbigou
# Processing Record 48 of Set 14 | havoysund
# Processing Record 49 of Set 14 | urdoma
# Processing Record 50 of Set 14 | pryluky
# Processing Record 1 of Set 15 | mandalgovi
# Processing Record 2 of Set 15 | wajima
# Processing Record 3 of Set 15 | lorengau
# Processing Record 4 of Set 15 | preobrazheniye
# Processing Record 5 of Set 15 | las palmas
# Processing Record 6 of Set 15 | domoni
# Processing Record 7 of Set 15 | nabire
# Processing Record 8 of Set 15 | jaguariaiva
# Processing Record 9 of Set 15 | pundaguitan
# Processing Record 10 of Set 15 | muroto
# Processing Record 11 of Set 15 | srednekolymsk
# Processing Record 12 of Set 15 | sogdiondon
# City not found. Skipping...
# Processing Record 13 of Set 15 | omboue
# Processing Record 14 of Set 15 | nueva concepcion
# Processing Record 15 of Set 15 | presidente medici
# Processing Record 16 of Set 15 | melo
# Processing Record 17 of Set 15 | tshane
# Processing Record 18 of Set 15 | tokomaru
# Processing Record 19 of Set 15 | ostrovnoy
# Processing Record 20 of Set 15 | dabat
# Processing Record 21 of Set 15 | the valley
# Processing Record 22 of Set 15 | sao felix do xingu
# Processing Record 23 of Set 15 | san rafael
# Processing Record 24 of Set 15 | kedougou
# Processing Record 25 of Set 15 | kindu
# Processing Record 26 of Set 15 | atasu
# Processing Record 27 of Set 15 | grand gaube
# Processing Record 28 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 29 of Set 15 | syamzha
# Processing Record 30 of Set 15 | ojhar
# Processing Record 31 of Set 15 | ulaangom
# Processing Record 32 of Set 15 | amalapuram
# Processing Record 33 of Set 15 | el dorado
# Processing Record 34 of Set 15 | tromso
# Processing Record 35 of Set 15 | avera
# Processing Record 36 of Set 15 | maragogi
# Processing Record 37 of Set 15 | ankang
# Processing Record 38 of Set 15 | ekangala
# Processing Record 39 of Set 15 | palang
# Processing Record 40 of Set 15 | santo angelo
# Processing Record 41 of Set 15 | wismar
# Processing Record 42 of Set 15 | seoul
# Processing Record 43 of Set 15 | rameswaram
# Processing Record 44 of Set 15 | toyo
# Processing Record 45 of Set 15 | nortelandia
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Ghanzi -21.5667   21.7833     62.42        35           0
# 1     Deer Lake  49.1667  -57.4316     46.26        76          75
# 2  Punta Arenas -53.1500  -70.9167     50.11        62          40
# 3     Tuatapere -46.1333  167.6833     51.55        89          60
# 4  Richards Bay -28.7830   32.0377     66.72        94           1
# 5        Yulara -25.2406  130.9889     42.64        61          12
# 6     Cape Town -33.9258   18.4232     60.12        89           9
# 7    Santa Cruz -17.8000  -63.1667     80.06        31           0
# 8        Albany  42.6001  -73.9662     68.92        41         100
# 9     Bonavista  48.6499  -53.1147     40.53        95         100
#
#    Wind Speed Country                 Date Current Description
# 0        4.07      BW  2022-05-05 19:41:42           clear sky
# 1       13.80      CA  2022-05-05 19:41:42       broken clouds
# 2       27.63      CL  2022-05-05 19:39:08    scattered clouds
# 3        4.38      NZ  2022-05-05 19:41:43       broken clouds
# 4        7.18      ZA  2022-05-05 19:38:27           clear sky
# 5        4.61      AU  2022-05-05 19:41:43          few clouds
# 6        2.30      ZA  2022-05-05 19:38:28                mist
# 7        4.61      BO  2022-05-05 19:36:48           clear sky
# 8        1.01      US  2022-05-05 19:37:25     overcast clouds
# 9       15.68      CA  2022-05-05 19:41:44          light rain

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Ghanzi      BW -21.5667   21.7833     62.42        35           0
# 1     Deer Lake      CA  49.1667  -57.4316     46.26        76          75
# 2  Punta Arenas      CL -53.1500  -70.9167     50.11        62          40
# 3     Tuatapere      NZ -46.1333  167.6833     51.55        89          60
# 4  Richards Bay      ZA -28.7830   32.0377     66.72        94           1
#
#    Wind Speed Current Description
# 0        4.07           clear sky
# 1       13.80       broken clouds
# 2       27.63    scattered clouds
# 3        4.38       broken clouds
# 4        7.18           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
